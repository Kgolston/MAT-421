# %% [markdown]
# Kyla Golston\
# Module E: Differentiation and Taylor Approximation\
# Section 3.2, 3.3\
# Due Date: 2/20/22

# %%
#Section 3.2 Differentiation
#How to find a derivative and plot it against the originial equation

# importing the library
import matplotlib.pyplot as plt
from scipy.misc import derivative
import numpy as np
  
# defining the function
def function(x):
    return 5*x**2
  
# calculating its derivative
def deriv(x):
    return derivative(function, x)
  
# defininf x-axis intervals
y = np.linspace(-6, 6)
  
# plotting the function
plt.plot(y, function(y), color='purple', label='Function')
  
# plotting its derivative
plt.plot(y, deriv(y), color='green', label='Derivative')
  
# formatting
plt.legend(loc='upper left')
plt.grid(True)

# %%
#Section 3.3 Unconstrained Optimization
#Gradient
from numpy import *

x = np.array([0., 1., 1.5, 3, 4., 10.], dtype=float)
np.gradient(f, x)
# Out:
# array([1.        , 3.        , 3.5       , 3.2       , 3.54761905,
#        0.83333333])
